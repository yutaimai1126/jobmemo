# %%
from wordcloud import WordCloud

wordcloud = WordCloud(
    font_path="NotoSansJP-Regular.ttf"
).generate(" ".join(["hoge", "fuga", "piyo", "ほげ", "ふが", "ぴよ"]))

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager

# フォントを全て読み込み
fonts = set([f.name for f in font_manager.fontManager.ttflist])

 
# 描画領域のサイズ調整
plt.figure(figsize=(10,len(fonts)/4))
 
# フォントの表示
for i, font in enumerate(fonts):
    plt.text(0, i, f"日本語：{font}", fontname=font)
    print(font)
# 見やすいように軸を消す
plt.ylim(0, len(fonts))
plt.axis("off")
    
plt.show()
# Out:
# Kalapi
# cmex10
# IBM Plex Sans KR
# Samyak Devanagari
# PlemolJP35 Console NF
# Ponnala
# KacstTitle
# Ramaraja
# Pothana2000
# Gidugu
# FreeMono
# IBM Plex Sans Hebrew
# cmb10
# Tlwg Mono
# Saab
# Lohit Kannada
# Padauk
# Open Sans Condensed
# Noto Mono
# aakar
# cmss10
# IBM Plex Sans Arabic
# Gubbi
# Ubuntu
# STIXSizeFourSym
# Gurajada
# Sawasdee
# Suruma
# Pagul
# Suranna
# Padauk Book
# Chandas
# DejaVu Serif Display
# Lohit Tamil
# KacstQurn
# D050000L
# URW Gothic
# Manjari
# Loma
# Nimbus Mono PS
# Timmana
# Kinnari
# KacstBook
# Potti Sreeramulu
# Uroob
# FreeSerif
# Waree
# STIXNonUnicode
# Tibetan Machine Uni
# IBM Plex Sans Condensed
# Z003
# Noto Sans Mono
# DejaVu Sans Mono
# C059
# IBM Plex Sans JP
# ori1Uni
# mry_KacstQurn
# Purisa
# cmtt10
# Noto Sans CJK JP
# KacstNaskh
# RaviPrakash
# KacstLetter
# KacstTitleL
# Mallanna
# Lohit Telugu
# IBM Plex Mono
# Umpush
# KacstPen
# Liberation Sans Narrow
# TenaliRamakrishna
# DejaVu Serif
# KacstArt
# Khmer OS
# Dhurjati
# Lohit Bengali
# Mandali
# Lohit Gurmukhi
# Keraleeyam
# cmmi10
# Vemana2000
# Likhan
# Samyak Tamil
# NTR
# Nimbus Sans
# OpenSymbol
# padmaa
# STIXSizeThreeSym
# Mukti
# Yrsa
# Sree Krushnadevaraya
# Khmer OS System
# Rachana
# AnjaliOldLipi
# Tlwg Typewriter
# KacstDecorative
# Ubuntu Condensed
# IBM Plex Sans Thai
# KacstPoster
# Suravaram
# Lohit Tamil Classical
# Syamala Ramana
# Chilanka
# Droid Sans Fallback
# KacstOne
# DejaVu Sans
# cmsy10
# Rasa
# Liberation Mono
# Peddana
# Liberation Serif
# Phetsarath OT
# Nakula
# IBM Plex Serif
# KacstScreen
# STIXSizeTwoSym
# Karumbi
# Ramabhadra
# Lohit Gujarati
# RaghuMalayalamSans
# cmr10
# STIXGeneral
# STIXSizeFiveSym
# Gayathri
# Samanata
# Liberation Sans
# KacstOffice
# IBM Plex Sans Thai Looped
# Samyak Gujarati
# Rekha
# Lohit Odia
# Tlwg Typo
# IBM Plex Sans Devanagari
# Norasi
# KacstFarsi
# Open Sans
# Tlwg Typist
# Nimbus Sans Narrow
# padmaa-Bold.1.1
# Jamrul
# Lato
# Ani
# Gargi
# LakkiReddy
# Standard Symbols PS
# URW Bookman
# Abyssinica SIL
# DejaVu Math TeX Gyre
# Nimbus Roman
# NATS
# LKLUG
# Dyuthi
# Noto Serif CJK JP
# Meera
# FreeSans
# STIXSizeOneSym
# Garuda
# Navilu
# DejaVu Sans Display
# Lohit Devanagari
# Samyak Malayalam
# Lohit Assamese
# P052
# Mitra
# IBM Plex Sans
# Sahadeva
# Lohit Malayalam
# Ubuntu Mono
# Laksaman
# Sarai
# KacstDigital
# Kalimati
# PlemolJP Console NF
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 108 (l) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 112 (p) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26412 (\N{CJK UNIFIED IDEOGRAPH-672C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 35486 (\N{CJK UNIFIED IDEOGRAPH-8A9E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 65306 (\N{FULLWIDTH COLON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 75 (K) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 97 (a) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 105 (i) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 83 (S) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 109 (m) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 121 (y) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 107 (k) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 68 (D) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 101 (e) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 118 (v) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 110 (n) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 103 (g) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 114 (r) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 80 (P) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 111 (o) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 99 (c) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 115 (s) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 116 (t) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 84 (T) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 104 (h) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 98 (b) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 76 (L) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 100 (d) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 71 (G) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 117 (u) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 73 (I) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 88 (X) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 122 (z) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 70 (F) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 106 (j) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 86 (V) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32 ( ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 102 (f) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 81 (Q) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 66 (B) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 78 (N) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 85 (U) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49 (1) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 95 (_) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 82 (R) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 65 (A) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 79 (O) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 77 (M) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 67 (C) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/hera/imai1126/.local/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 119 (w) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
